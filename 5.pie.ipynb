# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
cricketer = np.array(["Virat","Rohit","KL","surya","MSD"])
run = np.array([100,50,45,23,12])

# %%
plt.pie(run,labels = cricketer, autopct = '%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x232124ae4b0>,
# ...
#  [Text(0.22380166258348247, 1.0769924864291622, 'Virat'),
#   Text(-1.0592090493052229, -0.2967763296995337, 'Rohit'),
#   Text(-1.5448414976360635e-07, -1.0999999999999892, 'KL'),
#   Text(0.8810043814588506, -0.6586586975439618, 'surya'),
#   Text(1.085256606730559, -0.17949400421092948, 'MSD')],
#  [Text(0.12207363413644497, 0.5874504471431794, '43.48%'),
#   Text(-0.5777503905301214, -0.16187799801792746, '21.74%'),
#   Text(-8.426408168923981e-08, -0.5999999999999941, '19.57%'),
#   Text(0.4805478444321003, -0.3592683804785246, '10.00%'),
#   Text(0.5919581491257593, -0.0979058204786888, '5.22%')])
