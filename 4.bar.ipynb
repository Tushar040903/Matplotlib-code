# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
student = np.array(["Tushar","Jacob","Jack","Alex","Siri"])
marks = np.array([100,50,89,56,40])
plt.xlabel("student")
plt.ylabel("marks")
plt.title("marks of students")
plt.bar(student,marks)
# Out:
# <BarContainer object of 5 artists>
