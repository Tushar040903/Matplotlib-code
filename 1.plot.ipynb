# %%
# import the libraries
import matplotlib.pyplot as plt
import numpy as np

# %%
# xpts for x-axis and ypts for y-axis
xpts = np.array([1,10])
ypts = np.array([0,125])

# %%
#plot using pyplot using submodule
plt.plot(xpts,ypts)
